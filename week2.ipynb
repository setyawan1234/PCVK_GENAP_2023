# %% [markdown]
# <a href="https://colab.research.google.com/github/setyawan1234/PCVK_GENAP_2023/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np 

img = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2 = (510,150), color= (0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2 = (300,300), color= (0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100),radius=50, color= (255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0),pt2=(512,512), color= (255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True, color = (255,0,0), thickness=5)
plt.imshow(black_img2)

# %%
# tugas 2 - red-blue
image = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')

# memisahkan gambar dari biru, merah, hijau cahnnel
b,g,r = cv.split(image)
# membuat variable baru dengan nama new_image dengan red channel dan blue channel
new_image = cv.merge((r,g*0,b))

plt.imshow(new_image)

# %%
# tugas 2 - green-blue
image = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')

# memisahkan gambar dari biru, merah, hijau cahnnel
b,g,r = cv.split(image)
# membuat variable baru dengan nama new_image dengan green channel dan blue channel
new_image = cv.merge((r*0,g,b))

plt.imshow(new_image)

# %%
# tugas 3 - baris ke 20-115, kolom 25-120!
image = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')
plt.imshow(image[20:115,25:120])

# %%
# tugas 4 - menampilkan baris 5:30 dengan red channel saja 
image = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')
plt.imshow(image[5:30],cmap='Reds')

# %%
# tugas 5 - buat 5 kotak berbagai ukuran dan warna berbeda dalam 1 image
image = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')

image_new = image

cv.rectangle(image_new, pt1=(500,300), pt2 = (200,200), color= (0,255,0), thickness=15)
cv.rectangle(image_new, pt1=(100,1500), pt2 = (1000,1000), color= (225,255,0), thickness=20)
cv.rectangle(image_new, pt1=(700,200), pt2 = (1200,800), color= (255,0,0), thickness=25)
cv.rectangle(image_new, pt1=(1000,700), pt2 = (1500,800), color= (225,0,255), thickness=30)
cv.rectangle(image_new, pt1=(500,500), pt2 = (1000,1500), color= (0,255,255), thickness=35)

plt.imshow(image_new)

# %%
image_new = cv.flip(cv.cvtColor(image_new,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(image_new)

# %%
# tugas 7
image1 = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')

cv.rectangle(image1, pt1=(400,300), pt2 = (1500,1500), color= (225,0,255), thickness=30)
cv.circle(image1, center=(1000,900),radius=500, color= (255,0,0), thickness=10)

plt.imshow(image1)

# %%
# tugas 8
image1 = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')

cv.rectangle(image1, pt1=(20,1500), pt2 = (500,2000), color= (0,0,255), thickness=30)

plt.imshow(image1)

# %%
# tugas 9
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(image1, text='Hello', org=(10,1700),fontFace=font,fontScale=7,color=(255,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(image1)
